# %%
import numpy as np
import pandas as pd 
import tensorflow as tf
from matplotlib import pyplot as plt 
import sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## IMPORT & EXPLORE

# %%
lung_scans = np.load(r"C:\Users\User\Desktop\pneumonia_detection_project\data\arrays\pneumonia_detection.npz")['images']
lung_scans_labels = np.load(r"C:\Users\User\Desktop\pneumonia_detection_project\data\arrays\pneumonia_detection.npz")['labels']

# %% [markdown]
# #### FUNCTIONS

# %%
def generate_augmented_images(images, labels, augmentations_per_image=3):
    augmented_images = []
    augmented_labels = []

    for img, lbl in zip(images, labels):
        for _ in range(augmentations_per_image):
            # Apply random augmentations
            aug_img = tf.image.random_flip_left_right(img)
            aug_img = tf.image.random_flip_up_down(aug_img)
            aug_img = tf.image.rot90(aug_img, k=np.random.randint(4))
            aug_img = tf.image.random_brightness(aug_img, max_delta=0.1)
            aug_img = tf.image.random_contrast(aug_img, lower=0.8, upper=1.2)

            # Append new augmented image and corresponding label
            augmented_images.append(aug_img.numpy())  # Convert to NumPy for consistency
            augmented_labels.append(lbl)

    return np.array(augmented_images), np.array(augmented_labels)

# %%
def display_examples(images, labels, num_examples=5):
    plt.figure(figsize=(10, 10))
    
    for i in range(num_examples):
        ax = plt.subplot(1, num_examples, i + 1)
        ax.imshow(images[i])  # Display the image
        ax.set_title(f"Label: {labels[i]}")  # Display the label
        ax.axis("off")  # Hide axes
    
    plt.show()

# %%
lung_scans , lung_scans_labels = generate_augmented_images( images = lung_scans ,
                                                            labels = lung_scans_labels ,
                                                            augmentations_per_image = 2)

# %%
display_examples(images = lung_scans, 
                 labels = lung_scans_labels, 
                 num_examples=12)

# %%
lung_scans.shape
# Out:
# (11712, 224, 224, 1)

# %% [markdown]
# ## CLEAN & PREPARE

# %% [markdown]
# #### PREPARE DATA FOR MODEL BUILDING

# %%
lung_scans_train , lung_scans_test , lung_scans_labels_train , lung_scans_labels_test =  train_test_split(
    lung_scans ,
    lung_scans_labels ,
    train_size = 0.9 ,
    stratify = lung_scans_labels ,
    random_state = 42
)

lung_scans_train , lung_scans_validation , lung_scans_labels_train , lung_scans_labels_validation  =  train_test_split(
    lung_scans_train ,
    lung_scans_labels_train ,
    train_size = 0.9 ,
    stratify = lung_scans_labels_train ,
    random_state = 42
)

# %%
print(f'IMAGE ARRAYS SHAPES (TRAIN - TEST - VALIDATION) : {lung_scans_train.shape , lung_scans_test.shape , lung_scans_validation.shape }')
# Out:
# IMAGE ARRAYS SHAPES (TRAIN - TEST - VALIDATION) : ((9486, 224, 224, 1), (1172, 224, 224, 1), (1054, 224, 224, 1))

# %% [markdown]
# ## MODEL BUILD

# %%
from tensorflow.keras import models , layers , optimizers , losses , callbacks

# %% [markdown]
# #### STRUCTURE

# %%
lung_scans_sequential_neural_net = models.Sequential( [
   
    layers.Conv2D( filters = 32 ,
                   kernel_size = (3,3),
                   activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.BatchNormalization(),
    
    layers.Conv2D( filters = 64 ,
                   kernel_size = (3,3),
                   activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.BatchNormalization(),

    layers.Conv2D( filters = 128 ,
                   kernel_size = (3,3),
                   activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.BatchNormalization(),

    layers.Conv2D( filters = 256 ,
                   kernel_size = (3,3),
                   activation = 'relu'),
    layers.MaxPool2D(pool_size = (2,2)),
    layers.BatchNormalization()
    
] )

# %%
lung_scans_sequential_neural_net.add( layers.GlobalAveragePooling2D() )

lung_scans_sequential_neural_net.add( layers.Dense( units = 128 ,
                                                    activation = 'relu') )

lung_scans_sequential_neural_net.add( layers.Dropout(rate = 0.5) ) ,

lung_scans_sequential_neural_net.add( layers.Dense( units = 256 ,
                                                    activation = 'relu') ) 

lung_scans_sequential_neural_net.add( layers.Dense( units = 1 ,
                                                    activation = 'sigmoid') )

# %%
lung_scans_sequential_neural_net.build( input_shape = (lung_scans.shape) )

# %%
lung_scans_sequential_neural_net.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (11712, 222, 222, 32)       │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (11712, 111, 111, 32)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (11712, 111, 111, 32)       │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (11712, 109, 109, 64)       │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (11712, 54, 54, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (11712, 54, 54, 64)         │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (11712, 52, 52, 128)        │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (11712, 26, 26, 128)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (11712, 26, 26, 128)        │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (11712, 24, 24, 256)        │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (11712, 12, 12, 256)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (11712, 12, 12, 256)        │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (11712, 256)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (11712, 128)                │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (11712, 128)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (11712, 256)                │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (11712, 1)                  │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 455,937 (1.74 MB)
#  Trainable params: 454,977 (1.74 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# #### COMPILE

# %%
lung_scans_sequential_neural_net.compile( optimizer = optimizers.Adam() ,
                                          loss = losses.BinaryCrossentropy(),
                                          metrics = ['accuracy'] )

lung_scans_sequential_neural_net_early_stop = callbacks.EarlyStopping( monitor = 'val_loss',
                                                                       patience = 25 ,
                                                                       restore_best_weights = True )

# %% [markdown]
# #### TRAIN

# %%
training_history = lung_scans_sequential_neural_net.fit( lung_scans_train ,
                                                         lung_scans_labels_train,
                                                         validation_data = [lung_scans_validation,lung_scans_labels_validation],
                                                         epochs = 120,  
                                                         callbacks = [lung_scans_sequential_neural_net_early_stop],
                                                         batch_size = 32 ,
                                                         verbose  = 1 )
# Out:
# Epoch 1/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 130s 438ms/step - accuracy: 0.8448 - loss: 0.3553 - val_accuracy: 0.7296 - val_loss: 0.7082
# Epoch 2/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 126s 423ms/step - accuracy: 0.8744 - loss: 0.3055 - val_accuracy: 0.7306 - val_loss: 1.7805
# Epoch 3/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 131s 441ms/step - accuracy: 0.8993 - loss: 0.2597 - val_accuracy: 0.8786 - val_loss: 0.2856
# Epoch 4/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━
120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 124s 417ms/step - accuracy: 0.9904 - loss: 0.0286 - val_accuracy: 0.9459 - val_loss: 0.2393
# Epoch 26/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 123s 413ms/step - accuracy: 0.9867 - loss: 0.0346 - val_accuracy: 0.8880 - val_loss: 0.4425
# Epoch 27/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 119s 401ms/step - accuracy: 0.9936 - loss: 0.0213 - val_accuracy: 0.8311 - val_loss: 0.9148
# Epoch 28/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 120s 403ms/step - accuracy: 0.9929 - loss: 0.0201 - val_accuracy: 0.9089 - val_loss: 0.2589
# Epoch 29/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 120s 404ms/step - accuracy: 0.9954 - loss: 0.0148 - val_accuracy: 0.8672 - val_loss: 0.7365
# Epoch 30/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9897 - loss: 0.0317 - val_accuracy: 0.9535 - val_loss: 0.2000
# Epoch 31/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9932 - loss: 0.0179 - val_accuracy: 0.8861 - val_loss: 0.3717
# Epoch 32/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9970 - loss: 0.0125 - val_accuracy: 0.8529 - val_loss: 0.5240
# Epoch 33/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9928 - loss: 0.0230 - val_accuracy: 0.8861 - val_loss: 0.3998
# Epoch 34/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9936 - loss: 0.0173 - val_accuracy: 0.9516 - val_loss: 0.1525
# Epoch 35/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9929 - loss: 0.0158 - val_accuracy: 0.7315 - val_loss: 1.8696
# Epoch 36/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9926 - loss: 0.0194 - val_accuracy: 0.7837 - val_loss: 1.7156
# Epoch 37/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 119s 399ms/step - accuracy: 0.9940 - loss: 0.0170 - val_accuracy: 0.9497 - val_loss: 0.1976
# Epoch 38/120
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 118s 398ms/step - accuracy: 0.9950 - loss: 0.0152 - val_accuracy: 0.7941 - val_loss: 1.4509

# %%
lung_scans_sequential_neural_net.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (11712, 222, 222, 32)       │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (11712, 111, 111, 32)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (11712, 111, 111, 32)       │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (11712, 109, 109, 64)       │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (11712, 54, 54, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (11712, 54, 54, 64)         │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (11712, 52, 52, 128)        │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (11712, 26, 26, 128)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (11712, 26, 26, 128)        │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (11712, 24, 24, 256)        │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (11712, 12, 12, 256)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (11712, 12, 12, 256)        │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (11712, 256)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (11712, 128)                │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (11712, 128)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (11712, 256)                │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (11712, 1)                  │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,365,893 (5.21 MB)
#  Trainable params: 454,977 (1.74 MB)
#  Non-trainable params: 960 (3.75 KB)
#  Optimizer params: 909,956 (3.47 MB)

# %% [markdown]
# #### EVALUATE

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# %%
# Convert probabilities to class labels using a threshold of 0.5
predicted_labels = (lung_scans_sequential_neural_net.predict(lung_scans_test) >= 0.4).astype(int)

# Generate classification report
print(classification_report(lung_scans_labels_test, predicted_labels, zero_division=1))

# Display confusion matrix
ConfusionMatrixDisplay.from_predictions(lung_scans_labels_test, predicted_labels)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.89       317
#            1       0.95      0.96      0.96       855
#
#     accuracy                           0.94      1172
#    macro avg       0.92      0.92      0.92      1172
# weighted avg       0.94      0.94      0.94      1172

# %%
lung_scans_sequential_neural_net.evaluate( lung_scans_test ,
                                           lung_scans_labels_test )
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.9096 - loss: 0.1970
# [0.14668133854866028, 0.935153603553772]

# %% [markdown]
# #### SAVE

# %%
lung_scans_sequential_neural_net.save('lung_scans_sequential_neural_net.keras')

# %%
lung_scans_sequential_neural_net.save('lung_scans_sequential_neural_net.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
