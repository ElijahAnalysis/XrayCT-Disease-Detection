# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.ensemble import HistGradientBoostingClassifier 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import fetch_openml

# %%
credit_risk = fetch_openml( data_id = 31 )

credit_risk_data = credit_risk.data
credit_risk_data['type_code'] = credit_risk.target.astype('category').cat.codes

# %%
credit_risk_data.sample(5)
# Out:
#     checking_status  duration                  credit_history  \
# 969              <0        11  critical/other existing credit
# 337              <0        15                   existing paid
# 211     no checking        36                   existing paid
# 391        0<=X<200        12                   existing paid
# 352     no checking        18  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 969              new car           3939              <100      1<=X<4
# 337   domestic appliance           1275  no known savings      1<=X<4
# 211             radio/tv           3835  no known savings         >=7
# 391  furniture/equipment            983            >=1000          <1
# 352             used car           3229  no known savings  unemployed
#
#      installment_commitment     personal_status other_parties  ...  \
# 969                       1         male single          none  ...
# 337                       4  female div/dep/mar          none  ...
# 211                       2  female div/dep/mar          none  ...
# 391                       1  female div/dep/mar          none  ...
# 352                       2         male single          none  ...
#
#      property_magnitude age  other_payment_plans housing existing_credits  \
# 969         real estate  40                 none     own                2
# 337                 car  24                 none    rent                1
# 211         real estate  45                 none     own                1
# 391         real estate  19                 none    rent                1
# 352   no known property  38                 none     own                1
#
#                            job num_dependents  own_telephone foreign_worker  \
# 969         unskilled resident              2           none            yes
# 337                    skilled              1           none            yes
# 211         unskilled resident              1            yes            yes
# 391         unskilled resident              1           none            yes
# 352  high qualif/self emp/mgmt              1            yes            yes
#
#     type_code
# 969         1
# 337         0
# 211         1
# 391         1
# 352         1
#
# [5 rows x 21 columns]

# %%
credit_risk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   category
#  1   duration                1000 non-null   int64
#  2   credit_history          1000 non-null   category
#  3   purpose                 1000 non-null   category
#  4   credit_amount           1000 non-null   int64
#  5   savings_status          1000 non-null   category
#  6   employment              1000 non-null   category
#  7   installment_commitment  1000 non-null   int64
#  8   personal_status         1000 non-null   category
#  9   other_parties           1000 non-null   category
#  10  residence_since         1000 non-null   int64
#  11  property_magnitude      1000 non-null   category
#  12  age                     1000 non-null   int64
#  13  other_payment_plans     1000 non-null   category
#  14  housing                 1000 non-null   category
#  15  existing_credits        1000 non-null   int64
#  16  job                     1000 non-null   category
#  17  num_dependents          1000 non-null   int64
#  18  own_telephone           1000 non-null   category
#  19  foreign_worker          1000 non-null   category
#  20  type_code               1000 non-null   int8
# dtypes: category(13), int64(7), int8(1)
# memory usage: 70.9 KB

# %%
credit_risk_data_category_columns = credit_risk_data.select_dtypes(include = ('category'))

# %%
def cat_encoder( df ,
                 columns ):
    
    for column in columns:

        df[f"{column}_code"] = df[column].astype('category').cat.codes

    return df

# %%
credit_risk_data = cat_encoder( df = credit_risk_data ,
                                columns = credit_risk_data_category_columns.columns )

# %%
credit_risk_data.sample(5)
# Out:
#     checking_status  duration                  credit_history  \
# 167        0<=X<200        11                   existing paid
# 909        0<=X<200         9                   existing paid
# 798     no checking        24              delayed previously
# 185     no checking        15  critical/other existing credit
# 947     no checking        12                   existing paid
#
#                  purpose  credit_amount    savings_status  employment  \
# 167  furniture/equipment           1577            >=1000          <1
# 909              new car           3195  no known savings      1<=X<4
# 798              new car            717  no known savings         >=7
# 185             radio/tv           1360              <100      1<=X<4
# 947              new car           2859  no known savings  unemployed
#
#      installment_commitment     personal_status other_parties  ...  \
# 167                       4  female div/dep/mar          none  ...
# 909                       1  female div/dep/mar          none  ...
# 798                       4        male mar/wid          none  ...
# 185                       4         male single          none  ...
# 947                       4         male single          none  ...
#
#      savings_status_code employment_code  personal_status_code  \
# 167                    3               2                     0
# 909                    4               0                     0
# 798                    4               3                     2
# 185                    2               0                     3
# 947                    4               4                     3
#
#     other_parties_code property_magnitude_code  other_payment_plans_code  \
# 167                  2                       2                         1
# 909                  2                       2                         1
# 798                  2                       3                         1
# 185                  2                       0                         1
# 947                  2                       1                         1
#
#     housing_code  job_code own_telephone_code foreign_worker_code
# 167            1         3                  0                   1
# 909            1         2                  0                   1
# 798            1         3                  1                   1
# 185            1         3                  0                   1
# 947            1         0                  1                   1
#
# [5 rows x 34 columns]

# %%
credit_risk_data_independent = credit_risk_data.select_dtypes(include= ('number')).drop( columns = ['type_code'] )

credit_risk_data_dependent = credit_risk_data['type_code']

# %%
credit_risk_feature_scaler = StandardScaler()
credit_risk_data_independent = credit_risk_feature_scaler.fit_transform(credit_risk_data_independent)

# %%
credit_risk_data_independent_train , credit_risk_data_independent_test , credit_risk_data_dependent_train , credit_risk_data_dependent_test = train_test_split( 
    credit_risk_data_independent ,
    credit_risk_data_dependent ,
    train_size=0.9,
    stratify=credit_risk_data_dependent ,
    random_state=42
 )

# %%
credit_risk_hgb = HistGradientBoostingClassifier(max_iter=1500)

credit_risk_hgb.fit( credit_risk_data_independent_train ,
                     credit_risk_data_dependent_train )
# Out:
# HistGradientBoostingClassifier(max_iter=1500)

# %%
from sklearn.model_selection import cross_val_score

credit_risk_hgb_cross_val_scores = cross_val_score( estimator=credit_risk_hgb,
                                                    X=credit_risk_data_independent_train,
                                                    y=credit_risk_data_dependent_train,
                                                    cv=10,
                                                    scoring="f1_macro" )

# %%
np.mean(credit_risk_hgb_cross_val_scores)
# Out:
# 0.682687743874042

# %%
credit_risk_hgb_cross_val_scores
# Out:
# array([0.57887701, 0.69538462, 0.71486175, 0.6875    , 0.73360337,
#        0.70252404, 0.62139423, 0.67878001, 0.71920963, 0.69474279])

# %%
credit_risk_hgb = HistGradientBoostingClassifier(max_iter=4500)

credit_risk_hgb.fit( credit_risk_data_independent_train ,
                     credit_risk_data_dependent_train )
# Out:
# HistGradientBoostingClassifier(max_iter=4500)

# %%
credit_risk_hgb_cross_val_scores = cross_val_score( estimator=credit_risk_hgb,
                                                    X=credit_risk_data_independent_train,
                                                    y=credit_risk_data_dependent_train,
                                                    cv=10,
                                                    scoring="f1_macro" )

# %%
np.mean(credit_risk_hgb_cross_val_scores)
# Out:
# 0.674857857967076

# %%
credit_risk_hgb_cross_val_scores
# Out:
# array([0.56521739, 0.69538462, 0.68253968, 0.65909091, 0.73360337,
#        0.69246769, 0.61224187, 0.67878001, 0.71920963, 0.71004342])
